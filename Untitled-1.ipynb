# %%
import numpy as np
import pandas as pd
from format_data import *

# %%
file_path="welddb/welddb.data"
Db = create_dataframe(file_path)
# Out:
# C:\Users\Fathia\AppData\Local\Temp\ipykernel_18000\1640299071.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   Db[NUMERICAL_COL] = Db[NUMERICAL_COL].applymap(convert_less_than)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def column_info(col_title, table):
    col = table[col_title]
    missing_pct = col.isnull().mean() * 100
    
    # Plot the distribution
    plt.figure(figsize=(10, 6))
    if pd.api.types.is_numeric_dtype(col):
        sns.histplot(col.dropna(), kde=True)
    else: # the variable is categorical
        sns.countplot(y=col, order=col.value_counts().index)
    
    plt.title(f"{col_title}: {missing_pct:.2f}% missing")
    plt.xlabel(col_title)
    
    plt.show()

# %%
for col in COLUMNS:
    column_info(col, Db)
