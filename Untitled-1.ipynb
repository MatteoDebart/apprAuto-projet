# %%
import numpy as np
import pandas as pd
from format_data import *
from plots import *
# Out:
# C:\Users\linab\AppData\Local\Temp\ipykernel_27980\795824496.py:3: RankWarning: Polyfit may be poorly conditioned
#   from format_data import *

# %%
file_path="welddb/welddb.data"
Db = create_dataframe(file_path)
Db.to_excel('table.xlsx')
# Out:
# c:\Users\linab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
threshold = 30
table=Db.copy()
table['output']=table['Yield strength / MPa']
features = list(set(table.columns) - set(MECHANICAL_PROPERTIES))
table = table[features]
col_info = get_corr(table, threshold)

# %%
print(len(plot_completeness_vs_corr(col_info)))
# Out:
# 19

# %%
for col in Db.columns:
    column_info(col, Db)
