# %%
import numpy as np
import pandas as pd
from format_data import *
from preprocess import *
from plots import *
from utils import *

# %%
Db=create_dataframe()
# Out:
# c:\Users\linab\Desktop\3A\ApprAuto\apprAuto-projet\format_data.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   Db[NUMERICAL_COL] = Db[NUMERICAL_COL].applymap(convert_less_than)

# %% [markdown]
# # Supervised

# %%
plot_completeness_vs_corr(Db, OutputColumn.ch_imp_toughness, feature_decision=feature_decision)

# %%
preprocessed_Db = preprocess_supervised(Db, output_col=OutputColumn.yield_strength, all_welds=False)
y=preprocessed_Db['output']
X=preprocessed_Db.drop('output', axis=1)
# Out:
# We retain only the rows with output values Yield strength / MPa, that is 47.215496% of the dataset

# %% [markdown]
# # PCA

# %%
from dataset_analysis.PCA import *

# %%
pca_datset=preprocess_PCA(Db)
pca_datset.describe()
# Out:
#        Chromium concentration / (weight%)  \
# count                         1652.000000
# mean                            -0.190206
# std                              0.862470
# min                             -2.209153
# 25%                             -0.694724
# 50%                             -0.378514
# 75%                              0.065703
# max                              2.920556
#
#        Molybdenum concentration / (weight%)  \
# count                           1652.000000
# mean                              -0.365134
# std                                0.970674
# min                               -3.097656
# 25%                               -1.004277
# 50%                               -0.617502
# 75%                                0.274783
# max                                2.492730
#
#        Titanium concentration / parts per million by weight  \
# count                                        1652.000000
# mean                                           -0.124588
# std                                             1.139174
# min                                            -5.775260
# 25%                                            -0.728901
# 50%                                            -0.379612
# 75%                                             0.350127
# max                                             6.287688
#
#        Vanadium concentration / (weight%)  Cobalt concentration / (weight%)  \
# count                         1652.000000                       1652.000000
# mean                            -0.022615                         -1.065860
# std                              0.982201                          2.591625
# min                             -3.263897                        -18.066933
# 25%                             -0.237711                         -2.286954
# 50%                             -0.206847                         -0.735453
# 75%                              0.322583                         -0.006196
# max                             14.659838                         22.357878
#
#        Boron concentration / parts per million by weight  \
# count                                        1652.000000
# mean                                            0.214289
# std                                             1.036492
# min                                            -7.498104
# 25%                                            -0.393843
# 50%                                            -0.066121
# 75%                                             0.783119
# max                                             6.970965
#
#        Nickel concentration / (weight%)  Interpass temperature / °C  \
# count                       1652.000000                 1652.000000
# mean                           0.209397                   -0.013613
# std                            0.991459                    1.003696
# min                           -2.486006                   -4.676541
# 25%                           -0.501782                   -0.123999
# 50%                           -0.118480                   -0.123999
# 75%                            0.764851                   -0.123999
# max                            3.922965                    2.405191
#
#        Sulphur concentration / (weight%)  Carbon concentration / (weight%)  \
# count                        1652.000000                      1.652000e+03
# mean                            0.001245                      4.129062e-16
# std                             0.999515                      1.000303e+00
# min                            -0.796824                     -1.947250e+00
# 25%                            -0.314099                     -5.764332e-01
# 50%                            -0.225014                     -6.368496e-02
# 75%                             0.042240                      4.385990e-01
# max                            11.623235                      4.373157e+00
#
#        ...  Nitrogen concentration / parts per million by weight  \
# count  ...                                        1652.000000
# mean   ...                                          -0.017548
# std    ...                                           0.955155
# min    ...                                          -2.180444
# 25%    ...                                          -0.457020
# 50%    ...                                          -0.296036
# 75%    ...                                           0.058707
# max    ...                                           4.575533
#
#        Copper concentration / (weight%)  \
# count                       1652.000000
# mean                          -0.080523
# std                            1.194388
# min                          -10.812907
# 25%                           -0.533126
# 50%                           -0.239104
# 75%                            0.408246
# max                            4.517805
#
#        Post weld heat treatment time / hours  Voltage / V  \
# count                            1652.000000  1652.000000
# mean                               -0.002702    -0.055869
# std                                 0.999521     1.009195
# min                                -1.501237    -7.083032
# 25%                                -0.828603    -0.526436
# 50%                                -0.500421    -0.526436
# 75%                                 0.812308     0.190630
# max                                 3.109584     3.804639
#
#        Niobium concentration / parts per million by weight  \
# count                                        1652.000000
# mean                                           -0.049562
# std                                             0.887365
# min                                            -2.860019
# 25%                                            -0.569441
# 50%                                            -0.332009
# 75%                                             0.295136
# max                                             3.783926
#
#        Post weld heat treatment temperature / °C  \
# count                                1652.000000
# mean                                   -0.001987
# std                                     0.998154
# min                                    -1.067493
# 25%                                    -1.067493
# 50%                                    -0.191563
# 75%                                     0.964665
# max                                     1.595334
#
#        Tin concentration / parts per million by weight  Current / A  \
# count                                      1652.000000  1652.000000
# mean                                         -0.246519    -0.028192
# std                                           1.149649     0.956304
# min                                          -5.710894    -1.788775
# 25%                                          -0.468589    -0.591419
# 50%                                          -0.050191    -0.591419
# 75%                                           0.303479     0.083932
# max                                          10.793449     3.200939
#
#        Heat input / kJmm-1  Phosphorus concentration / (weight%)
# count         1.652000e+03                           1652.000000
# mean          3.440885e-17                              0.006762
# std           1.000303e+00                              1.002812
# min          -8.481709e-01                             -0.558207
# 25%          -5.400215e-01                             -0.303376
# 50%          -5.400215e-01                             -0.150477
# 75%           2.303519e-01                              0.053387
# max           4.775555e+00                             12.081401
#
# [8 rows x 27 columns]

# %%
pca, principal_components, nb_relevant_features = run_PCA(pca_datset)

# %%
pca_datset.columns
# Out:
# Index(['Chromium concentration / (weight%)',
#        'Molybdenum concentration / (weight%)',
#        'Titanium concentration / parts per million by weight',
#        'Vanadium concentration / (weight%)',
#        'Cobalt concentration / (weight%)',
#        'Boron concentration / parts per million by weight',
#        'Nickel concentration / (weight%)', 'Interpass temperature / °C',
#        'Sulphur concentration / (weight%)', 'Carbon concentration / (weight%)',
#        'Arsenic concentration / parts per million by weight',
#        'Aluminium concentration / parts per million by weight',
#        'Oxygen concentration / parts per million by weight',
#        'Antimony concentration / parts per million by weight',
#        'Manganese concentration / (weight%)',
#        'Tungsten concentration / (weight%)',
#        'Silicon concentration / (weight%)',
#        'Nitrogen concentration / parts per million by weight',
#        'Copper concentration / (weight%)',
#        'Post weld heat treatment time / hours', 'Voltage / V',
#        'Niobium concentration / parts per million by weight',
#        'Post weld heat treatment temperature / °C',
#        'Tin concentration / parts per million by weight', 'Current / A',
#        'Heat input / kJmm-1', 'Phosphorus concentration / (weight%)'],
#       dtype='object')

# %%
plot_PCA(pca, principal_components, 2, pca_datset.columns)

# %%
from plots import column_info
column_info('Cobalt concentration / (weight%)', Db)

# %%
plot_explained_variance_pca(pca, nb_relevant_features)

# %% [markdown]
# # Semi supervised learning

# %%
from semisupervised import *
from models.evaluation import *

# %%
Db_complete = preprocess_semisupervised(Db, OutputColumn.yield_strength, Models.regressions)

# %%
def evaluation_semi(Db, output_col:OutputColumn, model:Models):
    Db_complete = preprocess_semisupervised(Db, output_col, model)

    y_complete = Db_complete['output']
    X_complete = Db_complete.drop(['output'], axis=1)

    
    X_train, X_test, y_train, y_test = train_test_split(X_complete, y_complete, test_size=0.2, random_state=42)
    
    model_instance = model.value  # Extract the model from the Enum
    model_instance.fit(X_train, y_train)

    return evaluation(model_instance, X_test, y_test)

# %%
evaluation_semi(Db, OutputColumn.yield_strength, Models.randomforest)
# Out:
# {'MSE': np.float64(1785.826116760136),
#  'R²': 0.7618637458235826,
#  'Bias': np.float64(0.0970486246582795),
#  'Variance': np.float64(4236.713098425663)}
